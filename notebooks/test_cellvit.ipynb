# %%
import os 
os.chdir("..")

# %%
from src.models.vit import CellViT
a=CellViT(
    num_classes=2,
    embed_dim=384,
    input_channels=3,
    depth=12,
    num_heads=6,
    extract_layers=[3, 6, 9, 12],
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from src.models.vit import CellViT
# ----> 2 a=CellViT(
#       3     num_classes=2,
#       4     embed_dim=768,
#       5     input_channels=3,
#       6     depth=12,
#       7     num_heads=12,
#       8 )
#
# TypeError: CellViT.__init__() missing 1 required positional argument: 'extract_layers'

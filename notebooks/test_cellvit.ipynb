# %%
import os 
os.chdir("..")

# %%
from src.models.vit import CellViT
import torch
a=CellViT(
    num_classes=2,
    embed_dim=384,
    input_channels=16,
    depth=12,
    num_heads=6,
    extract_layers=[3, 6, 9, 12],
)
device = "cuda:0"
a = a.to(device)

# %%
a.eval()
random_input = torch.randn(64, 16, 256, 256).to(device)
with torch.no_grad():
    out=a(random_input)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 4
#       2 random_input = torch.randn(64, 16, 256, 256).to(device)
#       3 with torch.no_grad():
# ----> 4     out=a(random_input)
#
# File ~/miniconda3/envs/iscat/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/iscat/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...

# %%
out["binary_map"].shape
# Out:
# torch.Size([64, 2, 256, 256])

# %%
out_size_mb = sum(v.element_size() * v.nelement() for v in out.values()) / (1024 ** 2)
print(f"Size of 'out' in MB: {out_size_mb:.2f} MB")
# Out:
# Size of 'out' in MB: 32.00 MB
